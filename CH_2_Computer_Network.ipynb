# %%
#
# Setup P2P Network Practice
#
#!pip install pycryptodomex
#!pip install trio

# !cat /etc/hosts
# Out:
# 127.0.0.1	localhost
# ::1	localhost ip6-localhost ip6-loopback
# fe00::0	ip6-localnet
# ff00::0	ip6-mcastprefix
# ff02::1	ip6-allnodes
# ff02::2	ip6-allrouters
# 172.28.0.12	98bacf3333c1

# %%
# P2P Network - File Transfer Praceice - Server Part
# It's complecated to implement the P2P Network in a colab environment
# It's good to run server part in a Linux based terminal and
# client part in separate terminal
import socket

def receive_file(file_path, host, port):
    # Create a socket and bind to the host and port
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.bind((host, port))
    sock.listen(1)
    print("Server listening on {}:{}...".format(host, port))

    # Wait for a client to connect
    conn, addr = sock.accept()
    print("Connection from {} established.".format(addr))

    # Open the file and receive data from the client
    with open(file_path, 'wb') as f:
        while True:
            data = conn.recv(1024)
            if not data:
                break
            f.write(data)
    conn.close()
    print("File received successfully!")

if __name__ == '__main__':
    file_path = input("Enter file path: ")
    host = input("Enter host IP: ")
    port = int(input("Enter port number: "))
    receive_file(file_path, host, port)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c711bb60e2f2> in <module>
#      27
#      28 if __name__ == '__main__':
# ---> 29     file_path = input("Enter file path: ")
#      30     host = input("Enter host IP: ")
#      31     port = int(input("Enter port number: "))
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#
# P2P Network - File Transfer Practice - Client Part
# It's complecated to implement the P2P Network in a colab environment
# It's good to run server part in a Linux based terminal and
# client part in separate terminal
#
import socket

def send_file(file_path, host, port):
    # Create a socket and connect to the server
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.connect((host, port))

    # Open the file and send data to the server
    with open(file_path, 'rb') as f:
        sock.sendall(f.read())
    sock.close()
    print("File sent successfully!")

if __name__ == '__main__':
    file_path = input("Enter file path: ")
    host = input("Enter host IP: ")
    port = int(input("Enter port number: "))
    send_file(file_path, host, port)

# %%
#
# Distributed Networks - Similated Praceice
#
import multiprocessing

# Define a function that will be executed on a separate process
def process_function(input_data):
    # Perform some computation on the input data
    result = input_data * 2
    print("Process function result:", result,"\n")
    return result

if __name__ == '__main__':
    # Create a process pool with 4 worker processes
    with multiprocessing.Pool(processes=4) as pool:
        # Define the input data for the processes
        input_data = [1, 2, 3, 4]
        # Use the map function to apply the process function to the input data
        results = pool.map(process_function, input_data)
        print("All results:", results)

# In this example, the script creates a process pool with 4 worker processes using the multiprocessing.Pool class. 
# It then defines a function called process_function that takes an input data and performs some computation on it 
# (in this case, it multiplies the input by 2).
# The script then uses the map function of the process pool to apply the process_function to each element 
# of the input data. This is done in parallel across the 4 worker processes, which allows for faster computation times. 
# The results of each process are collected and returned in a list which is printed out.
# Out:
# Process function result:Process function result:Process function result: Process function result:     8426
#
#
#
#
#
#
#
# All results: [2, 4, 6, 8]

# %%
#
# Proof of Work (PoW) Practice
#
# To DO:
# Improve by adding a time limit for finding the nonce, 
# or increasing the difficulty target for better security.
#
import hashlib

# Difficulty target (number of leading zeros in the hash)
# Means that the output of the hash function should have 2 leading zeros
difficulty = 3

# Data to be hashed
data = b"Hello Kathmandu University!"

# Nonce - Number used in live data transmitting services in order to protect against replay attacks and other disruptions
# Find a nonce that meets the difficulty target
# Nonce starting with 0, it will keep increasing and test the hash meets the difficulty target
nonce = 0
while True:
    # Concatenate the data and nonce
    input_data = data + str(nonce).encode()
    print("Data and Nonce Value: ",input_data)
    # Hash the input data
    hashed_data = hashlib.sha256(input_data).hexdigest()
    print("Hash Data :",hashed_data)
    # Check if the hash meets the difficulty target
    if hashed_data[:difficulty] == "0" * difficulty:
        print("Found a valid nonce (Encode Format):", nonce)
        print("Hash:", hashed_data)
        break
    nonce += 1
# It keeps running to get changed hash value until it found the hash value 
# having two leading 0 in the beginning
# Out:
# Data and Nonce Value:  b'Hello Kathmandu University!0'
# Hash Data : 716321657e24ab8c09ad8a89a676c865bb96c6641eb091ee1c7294eec12e584b
# Data and Nonce Value:  b'Hello Kathmandu University!1'
# Hash Data : 31af776554a8391587b60134fbc1b4798d6e222acf581b48ca3516e90268169b
# Data and Nonce Value:  b'Hello Kathmandu University!2'
# Hash Data : 203e31b99e15514f6cdd40e7c5e0c7dec2d6b0b7707a68bd7d8328695c496694
# Data and Nonce Value:  b'Hello Kathmandu University!3'
# Hash Data : 66c3158d12e4a41c740697cd04b1d3045f2e7c0f6016af40a4b3c3bedab67b1b
# Data and Nonce Value:  b'Hello Kathmandu University!4'
# Hash Data : 1326340e6ac338ab6f2bc1b15eab1af327d6b425a3c7684c2a9c4ccc7e3fcf3f
# Data and Nonce Value:  b'Hello Kathmandu University!5'
# Hash Data : 8e2fe54ad9af908f64e9024aff7d1803179187ece6d3c0fc81f98824c6188ae6
# Data and Nonce Value:  b'Hello Kathmandu University!6'
# Hash Data : 7ef526c6915a8dfc5898d076591ce8677966431e70086a06bbcc0e2b89134ca6
# Data and Nonce Value:  b'Hello Kathmandu University!7'
# Hash Data : 568fea72b6f98d6e91d86fa797a37c73642f9c5b638ede4eb87b93e22aa2c9ed
# Data and Nonce Value:  b'Hello Kathmandu University!8'
# Hash Data : fb7a980a00b99bedbfcce3a258f455203596340df6e943a1147a0755d0552e61
# Data and Nonce Value:  b'Hello Kathmandu University!9'
# Hash Data : 5cde8498cb00e5295101359e9d43d9996d74becc3f5aaef31c292937cbcbd7b5
# Data and Nonce Value:  b'Hello Kathmandu University!10'
# Hash Data : fb3010f0bfb95aed6ab6464b74748929f42dc47119cd571e5896a04ce4196821
# Data and Nonce Value:  b'Hello Kathmandu University!11'
# Hash Data : 2eb61649a0924c13be1d6a3c0d7f7ae01f263629eabdd71318c34a175319a4ae
# Data and Nonce Value:  b'Hello Kathmandu University!12'
# Hash Data : 6c6ab8d4cc849942f36c619fea04af2c77e57c252111ff742deb774b04a5d919
# Data and Nonce Value:  b'Hello Kathmandu University!13'
# Hash Data : 2af07fc45a5e1d18bdabfc9082d768720b2269607c0d5c91d59e9432e54d6de2
# Data and Nonce Value:  b'Hello Kathmandu University!14'
# Hash Data : e819f29eb106d1c755d9ad0ded30c39409e7dc55084d5a02e510f9f672e7e5f0
# Data and Nonce Value:  b'Hello Kathmandu University!15'
# Hash Data : f8964c34544f51c1e97cb48b96f3aaf09f45d01a0972c8e13fcd18f871c68a1c
# Data and Nonce Value:  b'Hello Kathmandu University!16'
# Hash Data : 7d6cb57f910e8bdfe1046886891fd42ccce0291e46c868f5a167e1922a1ae266
# Data and Nonce Value:  b'Hello Kathmandu University!17'
# Hash Data : 2f68532b281aadf04921142a9ed0540a6111fead5839f9257c79a459a10060b9
# Data and Nonce Value:  b'Hello Kathmandu University!18'
# Hash Data : 00a762c132c84939eeb0d1e21880ed8c8375e314e3f4ee0b1500887aca292410
# Data and Nonce Value:  b'Hello Kathmandu University!19'
# Hash Data : c8f21924c1a5e4916d464cc141171a7c1927c2f1bd4fac2927628ecc49ac9380
# Data and Nonce Value:  b'Hello Kathmandu University!20'
# Hash Data : 0e98f667b992157c53937f3bdaa9f94f8696bf417549d01db92d7574819c6737
# Data and Nonce Value:  b'Hello Kathmandu University!21'
# Hash Data : d60aab6e7869868a8d44084fe59197218838e7519205884a673107d546cd8113
# Data and Nonce Value:  b'Hello Kathmandu University!22'
# Hash Data : 95689a7199cd605be4e58c698dd0befc3e0e1c8ccc53dc34e80b0970a3f2bca7
# Data and Nonce Value:  b'Hello Kathmandu University!23'
# Hash Data : ac797a0f6ef0cbe207e54e2e2eeadc25d6d678b796502628880e7f445444fc84
# Data and Nonce Value:  b'Hello Kathmandu University!24'
# Hash Data : 48f8b1c71d259effad8c0f36014f01f144f4fee2c1b6bbb5c1a666c39806e147
# Data and Nonce Value:  b'Hello Kathmandu University!25'
# Hash Data : d69add38f41c06e7cb1a227880d2a6f23b18da4247f2a0cdd1e9d0a24d485e54
# Data and Nonce Value:  b'Hello Kathmandu University!26'
# Hash Data : 0d723e2bb4061be229f2b4b2822e1ebf746c57371937a028ea7e5a5a69612b7d
# Data and Nonce Value:  b'Hello Kathmandu University!27'
# Hash Data : 6133a8cf4997d0b3b40fe78474f4cc0500ffb35ef8e9a79ca27ba00f41971706
# Data and Nonce Value:  b'Hello Kathmandu University!28'
# Hash Data : fa3bdc2ebbb687fdfa2c4c5cedbb3f0d3734297cde446cf3e1d2adba077cd504
# Data and Nonce Value:  b'Hello Kathmandu University!29'
# Hash Data : d1db55ab970d7e62f422f5455117f423737823bc42dd0ed911840b68fa216972
# Data and Nonce Value:  b'Hello Kathmandu University!30'
# Hash Data : dea7de85adaa106dbe8a25ddf671b96dd372d3b2159fc6cf4667dc2cc34a473c
# Data and Nonce Value:  b'Hello Kathmandu University!31'
# Hash Data : 1fcb402bee5141c831d30365c8f6aac22dfbc742e6ddd31fc7871b9c6e87088b
# Data and Nonce Value:  b'Hello Kathmandu University!32'
# Hash Data : 0fe6b762b989a3a221e3faf517b3240ab5cf152e14f37432764c372d534c0f5c
# Data and Nonce Value:  b'Hello Kathmandu University!33'
# Hash Data : 904bd875dcb6a7f81f941deb79370c2839c63733853a9cf364eddd418827d9e5
# Data and Nonce Value:  b'Hello Kathmandu University!34'
# Hash Data : 68db5ca9e53a4a2e35c19ae8e711808f4bfe0056eae9e6e568e51e11cf61cb03
# Data and Nonce Value:  b'Hello Kathmandu University!35'
# Hash Data : 2df6f04c257e2ac3d917a626d240ede5aedeedf20c6e3ad1e292992532f7c9a3
# Data and Nonce Value:  b'Hello Kathmandu University!36'
# Hash Data : 4659c7f33653d881e4c1f31159a542ec6f632ff73bb49a3bb6f342671ee55424
# Data and Nonce Value:  b'Hello Kathmandu University!37'
# Hash Data : 2d98c93d933fd20c50297037e40c8230d789135ccccb3a53afc3e1d1bfef0369
# Data and Nonce Value:  b'Hello Kathmandu University!38'
# Hash Data : 81682ecf2984152c8fc4952f840939695a9789ca17bf21a83ca7013679052d75
# Data and Nonce Value:  b'Hello Kathmandu University!39'
# Hash Data : c5222e7a4586b831f09a5397ef88145fbea3cd6d1ab6578d8cc944d257819431
# Data and Nonce Value:  b'Hello Kathmandu University!40'
# Hash Data : b9a97ddb19d7888a7db2adb900454649141d71e5fdbc33f54587ee440194493e
# Data and Nonce Value:  b'Hello Kathmandu University!41'
# Hash Data : 16902bdaac3863536e31f1124fed2584902b5ac55b83d8ac34dd1c5ce42aea9f
# Data and Nonce Value:  b'Hello Kathmandu University!42'
# Hash Data : d649864af2f23ed266841bb90fb536abda6b97418c5e1594645da09aa45be72d
# Data and Nonce Value:  b'Hello Kathmandu University!43'
# Hash Data : 909c63dc2fd5519c9388bb8906cc9b4f60a08f1484bf4a49ad712d185678a6c7
# Data and Nonce Value:  b'Hello Kathmandu University!44'
# Hash Data : 22a408d7776f0dc5639570f1dcb5d67a1d1053c4b2466fe4f2a0b4b3a8e3e8cb
# Data and Nonce Value:  b'Hello Kathmandu University!45'
# Hash Data : ae92b152fb968754d3bf8e50751d9b004d6dadb51aa0583e82186cb3e959b958
# Data and Nonce Value:  b'Hello Kathmandu University!46'
# Hash Data : 71bd935142c87136a7f94b10fe7ea8dc5c5eddcc29be57b1def088ccef95524a
# Data and Nonce Value:  b'Hello Kathmandu University!47'
# Hash Data : 9d6b3e3ffd3885c91e7e4e3fb87519d77cd84e89c5def021b5918697c689e6d9
# Data and Nonce Value:  b'Hello Kathmandu University!48'
# Hash Data : 879d8b7d0aa22d1e87957459a604e985d21738c5c14f2c3ea06b1163b18c896f
# Data and Nonce Value:  b'Hello Kathmandu University!49'
# Hash Data : 29d644b17c295674e09295116c928e3f225f6c6b1f4f9dc5b92fd62069d1368a
# Data and Nonce Value:  b'Hello Kathmandu University!50'
# Hash Data : 79b66181d6fbf11b1b793f91396abaa659efddcbebaa824bdaa772598d3872c5
# Data and Nonce Value:  b'Hello Kathmandu University!51'
# Hash Data : d0650b1fd500cc692f6f58d88292efc84fd5ba74a62c74cdf3fc3f67dcea41f3
# Data and Nonce Value:  b'Hello Kathmandu University!52'
# Hash Data : 7542d71a6317d24a2c64bd8fd0b2ff0f6c0b90c0b0c1bb41cc487927c40aecf3
# Data and Nonce Value:  b'Hello Kathmandu University!53'
# Hash Data : 71f8a1b109bfec695abe4f037a1978e898d2c80b126505b9dba36504d9e135ec
# Data and Nonce Value:  b'Hello Kathmandu University!54'
# Hash Data : a430429f0f43e25a2bf769f14a8aa7c5a1b5734ae9c3f57903617a33523203f3
# Data and Nonce Value:  b'Hello Kathmandu University!55'
# Hash Data : 9f45de18de69632833110f7f41f6c73d3710a07f5f323951681c33e1ce0ce4a9
# Data and Nonce Value:  b'Hello Kathmandu University!56'
# Hash Data : c305f37597ae90e215a1a03e9f84c84621901682223f835a629f5e6544076735
# Data and Nonce Value:  b'Hello Kathmandu University!57'
# Hash Data : c284a546f2899e140fccc7f3afbb20cce408d9d12f3a67fe85538d4ce947d8db
# Data and Nonce Value:  b'Hello Kathmandu University!58'
# Hash Data : d00e3b0a1322d4a93b9bd46f7dc60349882d3672da916d772fa1826a405597b0
# Data and Nonce Value:  b'Hello Kathmandu University!59'
# Hash Data : 62d48ba7238b08f885dce9f0b6dd30d89a9afd522f54be047f522033f0279b92
# Data and Nonce Value:  b'Hello Kathmandu University!60'
# Hash Data : 876924734283b52561edd3466b7c70e2d0e3c4bfd3eeebd8a10fe0d75735f886
# Data and Nonce Value:  b'Hello Kathmandu University!61'
# Hash Data : 695a11e06521a9c58807ae91ca083507915c32aef93ff901b2c2049c21b56977
# Data and Nonce Value:  b'Hello Kathmandu University!62'
# Hash Data : e72569b7cfb66ec50d2207ec9ad6c876defd6d797b35c00256c5a9af7375a11a
# Data and Nonce Value:  b'Hello Kathmandu University!63'
# Hash Data : b134afb4743b50b96a3d0d9e2590029cd3073321d3989d0d849f7bb5b1b14067
# Data and Nonce Value:  b'Hello Kathmandu University!64'
# Hash Data : 0b9413ccbdf23cbb2daf26352789156e223e1608e495df4329e4c8684d577bf5
# Data and Nonce Value:  b'Hello Kathmandu University!65'
# Hash Data : 2106a9fbb0f8595066b7ed563b6c0632c398d39143d6060c1cb0c9c630eb0f76
# Data and Nonce Value:  b'Hello Kathmandu University!66'
# Hash Data : c0e829c27973d021475e37407baabaab0f182545551deaeeb0fd2998bb6e388f
# Data and Nonce Value:  b'Hello Kathmandu University!67'
# Hash Data : 60d05f678e0572cdafabc0dd73db41b703f4d7fc157c9ad7e98ad1ebcfb91f57
# Data and Nonce Value:  b'Hello Kathmandu University!68'
# Hash Data : 90ffe947fe7af91c3e23ceb76da5b4a82fea6db4e1c1c97254eeb2bacbb48a64
# Data and Nonce Value:  b'Hello Kathmandu University!69'
# Hash Data : e3c3be5d6ae96125f9175a7ebace27785e0df116c57452b9038e4d7767f59ee6
# Data and Nonce Value:  b'Hello Kathmandu University!70'
# Hash Data : 6b7a464eba49d1b385c7d741642cff4e5cfdedda967829f5bfb080043f60cf69
# Data and Nonce Value:  b'Hello Kathmandu University!71'
# Hash Data : 72b5e178416229e9c58ccf20b2db6bc940ef30d62ae742799576cd48a0bde701
# Data and Nonce Value:  b'Hello Kathmandu University!72'
# Hash Data : d175d0ca8ee4124189b58d95048a7bce0a48537372d9f5a8451a43c9509dbe46
# Data and Nonce Value:  b'Hello Kathmandu University!73'
# Hash Data : 412cf9178bfa600f7d547cba17fa2680d2d375a2a9e5ba81b6d99b9a4252d73c
# Data and Nonce Value:  b'Hello Kathmandu University!74'
# Hash Data : f99f00edabdfa7ec7db19de543dde997242ad5716d29136c698a03a5cb82bfbf
# Data and Nonce Value:  b'Hello Kathmandu University!75'
# Hash Data : e295f48d817ae61b9acc05a66c30138972d80e25260b3fb6adcf4a7609aaf61a
# Data and Nonce Value:  b'Hello Kathmandu University!76'
# Hash Data : a3c68ecf8402eeb025c150072a7463ebf33b765e4aaaac46e9811e10264ba6d9
# Data and Nonce Value:  b'Hello Kathmandu University!77'
# Hash Data : e068a759ae12e1c1b83fae1201ca2a7722a1baa10dc1497f9752ca36a0428eb0
# Data and Nonce Value:  b'Hello Kathmandu University!78'
# Hash Data : e151a8cfbe617b143e25b60e75c44ba55018f69f7e8af974284b7ef1eda732ab
# Data and Nonce Value:  b'Hello Kathmandu University!79'
# Hash Data : 418c538daff0ad10fff503e1c6ea81315219a4f8eba1898d0b79c1c3dca21102
# Data and Nonce Value:  b'Hello Kathmandu University!80'
# Hash Data : 1c05426bb5c9039773965f82405c05f44ed0ffd638223581216b33d42d98ca43
# Data and Nonce Value:  b'Hello Kathmandu University!81'
# Hash Data : 8e68eda8b8f03c0842bf0866a2a14d7fe711f5477fbd8b01394809c0f41282e6
# Data and Nonce Value:  b'Hello Kathmandu University!82'
# Hash Data : 51e11f9e7539feb69994fca255676e4d1dfae8ab829a4eb1150cace9ac5c6480
# Data and Nonce Value:  b'Hello Kathmandu University!83'
# Hash Data : a8e7624accddd6f977a07d15515149f7bc3525eda5571cbbc4ca9cb01e18fb81
# Data and Nonce Value:  b'Hello Kathmandu University!84'
# Hash Data : 5116567682a83e8c5732340df34d5f5eb75f0565fb04f107d19027ef67ab1c7a
# Data and Nonce Value:  b'Hello Kathmandu University!85'
# Hash Data : cf5b729c55290d582b4f4fe64a74d59e5bd378932214f2c2af8b4954ae4937c9
# Data and Nonce Value:  b'Hello Kathmandu University!86'
# Hash Data : 1b11d81c1e4dea1305a34ec16aa9c51de399fff9b7f922f6f39a6ab26fa2e354
# Data and Nonce Value:  b'Hello Kathmandu University!87'
# Hash Data : ac9864c99531ed44c48b6bd27db1b65132d14a69837e8ba3c964312de9b786a1
# Data and Nonce Value:  b'Hello Kathmandu University!88'
# Hash Data : 77109007190ec928b873ba30b503ccad3396770c451dcac73c1afd7444e0ad3c
# Data and Nonce Value:  b'Hello Kathmandu University!89'
# Hash Data : 8bddb6ddcfe2fde697fb367db139ee0352ac1672488e12288f23d2966bad83fd
# Data and Nonce Value:  b'Hello Kathmandu University!90'
# Hash Data : 340e0387afa00f49f7c18e2a9ea57b229deda472ebf88421a01de07c4e5eefd3
# Data and Nonce Value:  b'Hello Kathmandu University!91'
# Hash Data : 4c93b614c590363092b3e34010a0fe31dfa2a976d77badf0ab4ca6c1bbed3260
# Data and Nonce Value:  b'Hello Kathmandu University!92'
# Hash Data : 623057357524de7c05f090eae3da5d07db2f717f6883135c18977786de0ffd1e
# Data and Nonce Value:  b'Hello Kathmandu University!93'
# Hash Data : 12a37c4eff9fd8ff874cb151e3af1d38562f9f5fc42e5a8991dca8ad415fab65
# Data and Nonce Value:  b'Hello Kathmandu University!94'
# Hash Data : 60e12ca66f3a74efa9f5dc814df892a3feb639817d6f34b3f74bb4f0dd60e78e
# Data and Nonce Value:  b'Hello Kathmandu University!95'
# Hash Data : 1048f52391c2699c5ed0ad4d6cdce733cb34c151529b70c15543ffce8b06d822
# Data and Nonce Value:  b'Hello Kathmandu University!96'
# Hash Data : 7441b1c9270e55c4f01d2bee57ab72a0f730ce027d2e8c64aa492539b68d350b
# Data and Nonce Value:  b'Hello Kathmandu University!97'
# Hash Data : c0e48c40e14cf49ea5efaba01560f749d7dbebbb6dcd7bf7b15ee348ac1cd2ae
# Data and Nonce Value:  b'Hello Kathmandu University!98'
# Hash Data : c17b29d1e61252396196d4dd614f04694bb5a5f55303465e344fd9bcf862776a
# Data and Nonce Value:  b'Hello Kathmandu University!99'
# Hash Data : 963c898eb68084a4aa2445f17ece115da3b046fd716e782ce03b729d415e7d4c
# Data and Nonce Value:  b'Hello Kathmandu University!100'
# Hash Data : 37cdd2eea42963563c9234aeca28f88a476188e3619b606f9fe281b209fd5f2a
# Data and Nonce Value:  b'Hello Kathmandu University!101'
# Hash Data : 8e7b1ddd471faca860af1b16311cb19c4eb6c31eab2a820c86f5bd7be82a5198
# Data and Nonce Value:  b'Hello Kathmandu University!102'
# Hash Data : dc42c271366e68d72e6fd2cbb490e865d7ca0cc5e8320314fd1f153a841508e1
# Data and Nonce Value:  b'Hello Kathmandu University!103'
# Hash Data : a1159dfd8ddd9851378b1b2fad6b21bbbf23086e3eb4e999832472e6b8b0368a
# Data and Nonce Value:  b'Hello Kathmandu University!104'
# Hash Data : 033e9c71dee4398aa6f31fa45de88f20685039f16770f74683e5b97d7b865796
# Data and Nonce Value:  b'Hello Kathmandu University!105'
# Hash Data : cf90a31d37d260508894c7d70f0d9f891c32fa75407afbcf57f25af961840ced
# Data and Nonce Value:  b'Hello Kathmandu University!106'
# Hash Data : 6a23c89cdabdec04b0d33a90ac505bf3af705006674b35edfdf5d1ec3508fda7
# Data and Nonce Value:  b'Hello Kathmandu University!107'
# Hash Data : 8f430ee1ef0e9401b6893ccd9ca21664ae07265e1a8d9303c33cc2dfb5187b63
# Data and Nonce Value:  b'Hello Kathmandu University!108'
# Hash Data : d2a55e2c72105450e878c5fb47f61a021ff7d4584a64935742afdef67cf62028
# Data and Nonce Value:  b'Hello Kathmandu University!109'
# Hash Data : 38d5ec0cb3e04a974046b08f921087f9a894bbd06a36e95691bb1046405e9320
# Data and Nonce Value:  b'Hello Kathmandu University!110'
# Hash Data : 2be43b2fd9ceb44d79657fd01f27dc6aa2afb061efda78267a8090315591cefe
# Data and Nonce Value:  b'Hello Kathmandu University!111'
# Hash Data : e44433a8732d4e77aec37cb7dda952dc1022d2b32444616c5c92e52a6ae4e178
# Data and Nonce Value:  b'Hello Kathmandu University!112'
# Hash Data : 44b8aa66b36ae60043e8bbf4d97ec446d3afd2aab148676bc6272d5565042a04
# Data and Nonce Value:  b'Hello Kathmandu University!113'
# Hash Data : f6f393e7f8881be98eb137b3bd183391e58c8f9ce8489db219928085a4655c0e
# Data and Nonce Value:  b'Hello Kathmandu University!114'
# Hash Data : d28e5f489f4e30b9888248664fbdb712cf1efc0ff1b689b5f4d797671b36ef65
# Data and Nonce Value:  b'Hello Kathmandu University!115'
# Hash Data : b7337102ecf27fea5391e6ab582b8feddbbd0a66720fe58ccf205d27cb27235b
# Data and Nonce Value:  b'Hello Kathmandu University!116'
# Hash Data : 118af14da68bb92883abae7209f560832c49aa585099a7636b74f05208330df3
# Data and Nonce Value:  b'Hello Kathmandu University!117'
# Hash Data : a5d377f61ee55e73e111a897d3423cc805c01598d07a1e2e8bb20ecb9ff6cf4a
# Data and Nonce Value:  b'Hello Kathmandu University!118'
# Hash Data : da2d21633893f79566d3e5dd5021b4b533718d1da6e750d2596022db9b4f508d
# Data and Nonce Value:  b'Hello Kathmandu University!119'
# Hash Data : c4a85f66e6faf51deed046be1e6df7ee4d410914ba1b63f7687a663d726e8dd5
# Data and Nonce Value:  b'Hello Kathmandu University!120'
# Hash Data : 2fc9add9ae7d59d1727e1ab412fb7332b3972b22e64c75137d7f40dbde8a8445
# Data and Nonce Value:  b'Hello Kathmandu University!121'
# Hash Data : d189d341d6ed24a65290ea3f43d3a4812d6d5a092b0866b702c02e12811ec615
# Data and Nonce Value:  b'Hello Kathmandu University!122'
# Hash Data : 0b3bc9d97110992e9c760578d4b96c73c3bf0238eb698aad9bb537cc0be0c66f
# Data and Nonce Value:  b'Hello Kathmandu University!123'
# Hash Data : 6f0c6df738e9deaa417ac7d73223867c6146888d8a813c8f1811445f349cdd87
# Data and Nonce Value:  b'Hello Kathmandu University!124'
# Hash Data : f90ec89880175d30abd1b675c07da2273ffc269df290d4b85ab90adde0ec2841
# Data and Nonce Value:  b'Hello Kathmandu University!125'
# Hash Data : f7f3643ead34b16f71d0f36cd5d23cba9e9830c5bcbc8978a100641874652aea
# Data and Nonce Value:  b'Hello Kathmandu University!126'
# Hash Data : 7aa3737c33f5814e45345f0d7727b2d4b3770f04ff297c21024fc97daf0ab923
# Data and Nonce Value:  b'Hello Kathmandu University!127'
# Hash Data : 9ba30a1a03e7f65e2f8d13eb573e6556012212c4eae6bccf6975f82a74f9c0ba
# Data and Nonce Value:  b'Hello Kathmandu University!128'
# Hash Data : 4410ab22627a598fc2a152f16b854d8c50d072744d2fd8aff07e7121ebbe6e66
# Data and Nonce Value:  b'Hello Kathmandu University!129'
# Hash Data : 41b6194d8a9b35a4de73fb2da957711f08ac2ef6a42c1714348b6097473ad18f
# Data and Nonce Value:  b'Hello Kathmandu University!130'
# Hash Data : ce5b09de0ac36ef51e4ee1a863dbc791b6594e81dde8f9fea8d1fdc6bacc649c
# Data and Nonce Value:  b'Hello Kathmandu University!131'
# Hash Data : b38ccbbbb9ca9fb6200ac92286dbf9526374470326cc65bfc3c90670875a8e62
# Data and Nonce Value:  b'Hello Kathmandu University!132'
# Hash Data : 98c87bd46a760fd7df0aacd70759c51ae95f5a0c3755ba983912041943870b96
# Data and Nonce Value:  b'Hello Kathmandu University!133'
# Hash Data : ee62c0ba2ecf3f133cc6738478a6da008d4863a8f98dbfe998742be56b82d9f6
# Data and Nonce Value:  b'Hello Kathmandu University!134'
# Hash Data : 4630ae4f2455e95d4c468fd2a86064cd927e81c30d5adb1d40caba6c161ae8e2
# Data and Nonce Value:  b'Hello Kathmandu University!135'
# Hash Data : b9816b8a1dd022328ff1873b0691333fe59c309308bc1245f7d68f6ce4b27fb5
# Data and Nonce Value:  b'Hello Kathmandu University!136'
# Hash Data : 65dd9d858a2c6d0b92ee81d2c3b475bd183c8fbb8464f8106a8cb750c4a0a8c4
# Data and Nonce Value:  b'Hello Kathmandu University!137'
# Hash Data : b8cdcc08b90aecb14f6a032bd3c0b7daa885e977c5c9a0d2c260def6c6ea892c
# Data and Nonce Value:  b'Hello Kathmandu University!138'
# Hash Data : bb304345c4b660796b9d24e884bbe10cd4a5dad85b808fe568d1a9ee35b50651
# Data and Nonce Value:  b'Hello Kathmandu University!139'
# Hash Data : 3effea852c45bae18e6387f20f706f963721e877acdc0d79a2e4df5366bb29ac
# Data and Nonce Value:  b'Hello Kathmandu University!140'
# Hash Data : 96c990d9eb98560e4c0187dccdd6c900be19e8679c717c7cf2aa189f22b5c8e1
# Data and Nonce Value:  b'Hello Kathmandu University!141'
# Hash Data : 2cca1ffefb16fdfda17622b8da9beec23748b38f4ab475cf498c2db8b060f47e
# Data and Nonce Value:  b'Hello Kathmandu University!142'
# Hash Data : b89b55a006538664fb5deb1a10943f74dd64703f1a524637d87612e344f71474
# Data and Nonce Value:  b'Hello Kathmandu University!143'
# Hash Data : d54e83d0c9df3251562fe7bd06a86698a82cef318b7d111229fce6b926e696aa
# Data and Nonce Value:  b'Hello Kathmandu University!144'
# Hash Data : 8a0d0c34a7245d6ce9f62b2b2cef6e346b934e885a90fff3fad8c88123524381
# Data and Nonce Value:  b'Hello Kathmandu University!145'
# Hash Data : 03f7eccaca56edb818e3c8597f1e9af86a151f0f300e32af7907757cdfd2c7dc
# Data and Nonce Value:  b'Hello Kathmandu University!146'
# Hash Data : 9eeb4783af687c378c2cb60c81b8ba90c1884c6d752b8e1869712e9da970ad8c
# Data and Nonce Value:  b'Hello Kathmandu University!147'
# Hash Data : 65309fb2654375f567aaaa961bdae2eef96cac10ce66178bb24a83ae4b3c723d
# Data and Nonce Value:  b'Hello Kathmandu University!148'
# Hash Data : 2da4472fc8fb7d5baf456f97979943b9a3467c65f62f42a527ec99130e8d6164
# Data and Nonce Value:  b'Hello Kathmandu University!149'
# Hash Data : 7cf4740887b2cd68c331c97cb4580b8838adcf194e473ff02442604434d6cf5e
# Data and Nonce Value:  b'Hello Kathmandu University!150'
# Hash Data : 781d66dd8cd15a7b216942ba3195fd8ee28f0d724c2375efc3fae0c763da130e
# Data and Nonce Value:  b'Hello Kathmandu University!151'
# Hash Data : e423f32104dc93da52daa886a5e30c9d3f117e8f84b4785596a8ea2661e687b0
# Data and Nonce Value:  b'Hello Kathmandu University!152'
# Hash Data : b66eecdc8330e1ed3bd79b3e3a50b40cae33bd69edbc60b1bc6f45e0e046691e
# Data and Nonce Value:  b'Hello Kathmandu University!153'
# Hash Data : 980903d338a4b5c7c249940b947af93fcfe12ec911b9cb8d928c3e0d04effcf1
# Data and Nonce Value:  b'Hello Kathmandu University!154'
# Hash Data : 762efc38570f5c79b56491c8a93c83e76db4732c181405bf8eb1593867fd1cd3
# Data and Nonce Value:  b'Hello Kathmandu University!155'
# Hash Data : 7d82a3ddd26eb3763ed808dcc243dd3d97db55caca1974a16f15b4c71254e8b3
# Data and Nonce Value:  b'Hello Kathmandu University!156'
# Hash Data : 47b5b5009519aa93f32c9383015e575b6cbae79dc55cb5f29e2fad1f83bb1edc
# Data and Nonce Value:  b'Hello Kathmandu University!157'
# Hash Data : 98598ddbf4aebc3756b5110d6876ff62d8ed078fe7ac4e189a3d55ffe75d6578
# Data and Nonce Value:  b'Hello Kathmandu University!158'
# Hash Data : 0656d5609e476e9fff77a663c6ced8340e0070ac8966df215e1d67f4eb952da4
# Data and Nonce Value:  b'Hello Kathmandu University!159'
# Hash Data : 088885296fa1a94eafbf4cacdd237813322be73de0b8879a0c23d71358dc6a86
# Data and Nonce Value:  b'Hello Kathmandu University!160'
# Hash Data : 48700f6234ef2396115564b8475d2cb03372102d408b77e5eeb22dca127c27a1
# Data and Nonce Value:  b'Hello Kathmandu University!161'
# Hash Data : df63f1ac07ac2bcec2c9b8ad8ff73015ac044eed0998b59e2771f75a97fedc31
# Data and Nonce Value:  b'Hello Kathmandu University!162'
# Hash Data : 8a13e5961e430374388cda69fd776bac09a5537731c8253b7b7d46449e54967d
# Data and Nonce Value:  b'Hello Kathmandu University!163'
# Hash Data : 55a78db50c8b7ea4570357175743a2f272cfdf187ba11693fee65fad6d2d4d75
# Data and Nonce Value:  b'Hello Kathmandu University!164'
# Hash Data : c580ab6a269311daa47eda21ba65297d89b671f2cf25d76db6b69b860d120296
# Data and Nonce Value:  b'Hello Kathmandu University!165'
# Hash Data : f9c31efd4353da9886288f6cb2c68e375f85a0bf0b38d8e573e9dc62c9e0fcc7
# Data and Nonce Value:  b'Hello Kathmandu University!166'
# Hash Data : aa5642a120b1c47bf83fb49497521f3ec91cac2142acf99bcf786af6c617b211
# Data and Nonce Value:  b'Hello Kathmandu University!167'
# Hash Data : 40736e7308a0ce781015993c3736aa3ad0d87c1867d061805cb86f0bbdb86d19
# Data and Nonce Value:  b'Hello Kathmandu University!168'
# Hash Data : fc9510b5196ed19acb3e2619e1ea26f71711ce14708af83c69446848c0594e1b
# Data and Nonce Value:  b'Hello Kathmandu University!169'
# Hash Data : 36eb3b610689d9e3be52798e8113ca78540b3173ac3420618a33979ac5c08b39
# Data and Nonce Value:  b'Hello Kathmandu University!170'
# Hash Data : aa61b60cb23060db26b1b049fc6865d51c92eb7e1637a9c4a48c4d6502d4b6d0
# Data and Nonce Value:  b'Hello Kathmandu University!171'
# Hash Data : 6755103921e63b87be87a13f110571498b65c98329dabf704f37ce04e0851206
# Data and Nonce Value:  b'Hello Kathmandu University!172'
# Hash Data : cfc637c6f9babb2b911b67726ef5273f5ca254264762dfdab58e081e42109695
# Data and Nonce Value:  b'Hello Kathmandu University!173'
# Hash Data : ac5c3e8574473db1d672847e2d167464f996986040ef62f71a658f4773972e3a
# Data and Nonce Value:  b'Hello Kathmandu University!174'
# Hash Data : 02248a70dc3b45a6c019a8fe28e005955e3d50c731df4c0f1dd1e9c2bf42b61f
# Data and Nonce Value:  b'Hello Kathmandu University!175'
# Hash Data : 918d8c295097027282d756330518509d748f0200afb4711dd556df0dbb530141
# Data and Nonce Value:  b'Hello Kathmandu University!176'
# Hash Data : c7a3e9d85306efd4f235161b539ada62db318574bfa59dbb61ae14eab9556270
# Data and Nonce Value:  b'Hello Kathmandu University!177'
# Hash Data : bad56f248362de1d4b04b8d156d45d3d7dedbf03a95e98f535321e3e227c1b00
# Data and Nonce Value:  b'Hello Kathmandu University!178'
# Hash Data : bf16e439e668dc8bfe024cb574adcbfc645975825dc07429267c097748fde554
# Data and Nonce Value:  b'Hello Kathmandu University!179'
# Hash Data : 0b6214e758f5a0c2237a5d6d42ee0f4d95f042e7a5bf7afa84cc81ab8665208e
# Data and Nonce Value:  b'Hello Kathmandu University!180'
# Hash Data : 35a7852b8aafa7f9000da6af5e96db5a53b9d3b73ae65f20e8ea26495a0b821d
# Data and Nonce Value:  b'Hello Kathmandu University!181'
# Hash Data : d481c04fbb4f03d0e6c2a414dd947139a0e72c63c959ef06895ea7b7c2784769
# Data and Nonce Value:  b'Hello Kathmandu University!182'
# Hash Data : b6f8223f3501da03890931c15750a77fdce14d659823cc461a6f26d58734be3b
# Data and Nonce Value:  b'Hello Kathmandu University!183'
# Hash Data : 5c106efdb961b89b0af7a0fdd0e9a1fd8ee542e5504cff2541a02efbd10b8717
# Data and Nonce Value:  b'Hello Kathmandu University!184'
# Hash Data : 40527517d710c7f6de6f95aa222636262f8973f55a5dec0fee79b26b30e5bb41
# Data and Nonce Value:  b'Hello Kathmandu University!185'
# Hash Data : 5a6dc19e45501b21ee5d74c5282789422b8003f66fcc5d192a19e076066c166f
# Data and Nonce Value:  b'Hello Kathmandu University!186'
# Hash Data : bf524acc90d6dcbbed20949ad0eb899863d87856034a9783de007a1445726cc2
# Data and Nonce Value:  b'Hello Kathmandu University!187'
# Hash Data : 7508bee287be8ac3c39858b051413da3abc44d8334bdd7865a454565ae061263
# Data and Nonce Value:  b'Hello Kathmandu University!188'
# Hash Data : ea88667e23032fc6a9466e469c5a5be22398b11635ed52a2367753761fe693cf
# Data and Nonce Value:  b'Hello Kathmandu University!189'
# Hash Data : 6e25a425251ffe1eaa3e4c1627b1245bfe500c8c3bc1a984386615fb8ae48d35
# Data and Nonce Value:  b'Hello Kathmandu University!190'
# Hash Data : 78fabdd32506d19fb3b0f528b68e55447b286e93650a52900a6eec22503f1d92
# Data and Nonce Value:  b'Hello Kathmandu University!191'
# Hash Data : 6c4139adebc19fc5709c3baf483549f5de37f8ae93f64cb65555f6f52ca52427
# Data and Nonce Value:  b'Hello Kathmandu University!192'
# Hash Data : 13df5a598e11c143aecd7de9ed14bf14fc7d1fdb4bee556ad7bbc06d9aa13f85
# Data and Nonce Value:  b'Hello Kathmandu University!193'
# Hash Data : 719895d0fe83425f820a0d30d38134fd64161038d6dfb4ebbc14ac474d5c71a1
# Data and Nonce Value:  b'Hello Kathmandu University!194'
# Hash Data : c5630f20d50fdd4b4562fc16c6efc62d8f5624ccfa20de75aeceeee208d0f47e
# Data and Nonce Value:  b'Hello Kathmandu University!195'
# Hash Data : ba4c6b2cb25e970bf104b9f7dc2cfda4f55493a35ff96524b568a6ea0a993cc8
# Data and Nonce Value:  b'Hello Kathmandu University!196'
# Hash Data : be968aff81a49e42725158267b130613b8b008b5e1df5f17952ae803b5f8989f
# Data and Nonce Value:  b'Hello Kathmandu University!197'
# Hash Data : 5ccf90f3a7a18c897b2cc96a07f28b5a413e361ef2f74274a919faf8cc086727
# Data and Nonce Value:  b'Hello Kathmandu University!198'
# Hash Data : 0b69a20e693cc63daba74cd5d8b6613b1bbc8cc260d79fb4cdd6bc3683ad8179
# Data and Nonce Value:  b'Hello Kathmandu University!199'
# Hash Data : b59899ffa80d7477c4aef551c3adfd6efa8e9e376383ac659fcebaabd918ea58
# Data and Nonce Value:  b'Hello Kathmandu University!200'
# Hash Data : f87222d3a66ce960d789378dbeeca313bc61db0be80fb207a74cb46f5cc36ba0
# Data and Nonce Value:  b'Hello Kathmandu University!201'
# Hash Data : 6cc0e0809bc53ec714bcd35203683d79cbf967cfa585e052bf5258bd841a7eb7
# Data and Nonce Value:  b'Hello Kathmandu University!202'
# Hash Data : 1ac11a3eec566b7d73ef5aa95a118ec0336f6ab26d2298dad058e51a0d09f5d3
# Data and Nonce Value:  b'Hello Kathmandu University!203'
# Hash Data : e4c313d626c86859418d94fc4ae57398db2d5ebfed99adf9e50167a119d2194c
# Data and Nonce Value:  b'Hello Kathmandu University!204'
# Hash Data : 8ec3199e9d2a08da4520a1deb6446ab40ef685d661fc52a640ceb378ba6b5d33
# Data and Nonce Value:  b'Hello Kathmandu University!205'
# Hash Data : d1350686ae70ae8da934be64dd0535abe5ec0e0c3dca7460ff58b53fdf2a327b
# Data and Nonce Value:  b'Hello Kathmandu University!206'
# Hash Data : 4e34f6e7e323916b7af6887436055dffedbc76ac02d8eb41b8cc91c9027ceb94
# Data and Nonce Value:  b'Hello Kathmandu University!207'
# Hash Data : 6ad18b413b816ea777b6b96445c6f764e41e7bb41b62572545942437aaafedff
# Data and Nonce Value:  b'Hello Kathmandu University!208'
# Hash Data : d211f7beeb446cec8246aaaed48ecf801d6f9721a1b225c5a4e0cf21ff98ef21
# Data and Nonce Value:  b'Hello Kathmandu University!209'
# Hash Data : d86e25b6a55ae6b0b4c8789b455b234254aceac0d24a7374f57d86a228c007ca
# Data and Nonce Value:  b'Hello Kathmandu University!210'
# Hash Data : 0601322fdf02da26c7cedab15904d6acc0185a883f8f555e9e58e8bc7a22518e
# Data and Nonce Value:  b'Hello Kathmandu University!211'
# Hash Data : 04a5608a40ed529fe0232cba9491387a19264b706b023880aa27cbe237a65ebb
# Data and Nonce Value:  b'Hello Kathmandu University!212'
# Hash Data : 26e62a5bb0a20b2e91ce7c4a79265155a8d0d66c0a48f5555872f32a2c8feb89
# Data and Nonce Value:  b'Hello Kathmandu University!213'
# Hash Data : b4d42077ef19322d6a25ae966576dc441c5a3adec68c808135d1583c717484b5
# Data and Nonce Value:  b'Hello Kathmandu University!214'
# Hash Data : e085a1d8f8726839fbb0f7b2aa7d455acbafb17fa7ffe1f35f155e13c87c4a58
# Data and Nonce Value:  b'Hello Kathmandu University!215'
# Hash Data : 503add41eb725b2c2c25d9fd85d2417a42c16779dcec43c79c661f461a4719e1
# Data and Nonce Value:  b'Hello Kathmandu University!216'
# Hash Data : 63e177d276bd68b2ce93825a5d5eb29ad9fefa1358e5e8b832117b1a141bf186
# Data and Nonce Value:  b'Hello Kathmandu University!217'
# Hash Data : b6c9f959322de0d167925db71923a96fe7a3c99ba930e26552ee07f727227a83
# Data and Nonce Value:  b'Hello Kathmandu University!218'
# Hash Data : 6ec89083f8e0ec7017193c9307938f231a246a645e9c8787ffc1d61852d0247a
# Data and Nonce Value:  b'Hello Kathmandu University!219'
# Hash Data : 99dcdefa255cea56ecd9001c680b15964d584bc193fb2c149fe7268c9ef4fef6
# Data and Nonce Value:  b'Hello Kathmandu University!220'
# Hash Data : 862df9ae614abd71300a7126eb22c050692c358f2f909d63eeddf2ecb8ac9589
# Data and Nonce Value:  b'Hello Kathmandu University!221'
# Hash Data : 9d5dda5bd8f14ad6d85a8f481927be028f113ac4f05b9313c60133bd41b662e1
# Data and Nonce Value:  b'Hello Kathmandu University!222'
# Hash Data : 419cad9f836fb64e18e0345b79c2d925e22c312cd1142b18328586335ce6621e
# Data and Nonce Value:  b'Hello Kathmandu University!223'
# Hash Data : 100d7e394477a2d81fa879fa3cb203e275301818e031a1a384fea01b6a11a1de
# Data and Nonce Value:  b'Hello Kathmandu University!224'
# Hash Data : 8296f26bdfdda8603e2362f63c0a534a9405b98370e859eda149407437b5699e
# Data and Nonce Value:  b'Hello Kathmandu University!225'
# Hash Data : 8f34739bbff67d8d5612eb0f04f8b1e12ebfa81d148ff2673930e5eb401add05
# Data and Nonce Value:  b'Hello Kathmandu University!226'
# Hash Data : 7762cbb46a46b4b2c95d4451a0d9aa10bd7900e2e0e88278c4fc53d8de131ede
# Data and Nonce Value:  b'Hello Kathmandu University!227'
# Hash Data : 6010dbc8f7dc1f355fb3a3c4347ae7eb62da0873df936b73a1e299a3c4579b82
# Data and Nonce Value:  b'Hello Kathmandu University!228'
# Hash Data : c86516fe9b99c9aad06c0458086af02daa60ddea3bb0f47bd021030a0e8d72be
# Data and Nonce Value:  b'Hello Kathmandu University!229'
# Hash Data : 63b26c8df801a9077a4b879744b6feae4b736cca3f60b71fd5ab2a7b30088567
# Data and Nonce Value:  b'Hello Kathmandu University!230'
# Hash Data : ea532024edbb04c39d90a3dd41f9c03cc23df0ba19adefa37fde3c710d6d7749
# Data and Nonce Value:  b'Hello Kathmandu University!231'
# Hash Data : a610d05589c59bc80bf48c390aa48e31d253d3684d03481e356605432da1b15a
# Data and Nonce Value:  b'Hello Kathmandu University!232'
# Hash Data : eb42b870da4c38236c8679069760beb70ab6ece6c8ef8f3e1ad9d3c87a7bb0a8
# Data and Nonce Value:  b'Hello Kathmandu University!233'
# Hash Data : 9c708236a98b96df3011f775b71c72e53ea56a95a59f71fbcdb6e7234a70a578
# Data and Nonce Value:  b'Hello Kathmandu University!234'
# Hash Data : 4ee71ecf387cfb8ce434cbd4f5703abb1de9460b617d2cf4bf5da977f205e46f
# Data and Nonce Value:  b'Hello Kathmandu University!235'
# Hash Data : 5f5a71f4ec6a0b42fe548d14671d31b08f45e697d6b5d782d271d40437fee2e4
# Data and Nonce Value:  b'Hello Kathmandu University!236'
# Hash Data : c5912abf56ec1bee382ece66cabebc4103fd3402f9fc9fb9f2aaf7ecf56b0d77
# Data and Nonce Value:  b'Hello Kathmandu University!237'
# Hash Data : abc8917582fa11f406fbc45f836376c38d47f5c86a76499903330645ecb2654a
# Data and Nonce Value:  b'Hello Kathmandu University!238'
# Hash Data : f94bc861de273ce4b21d4710da70df8e60bfcb0784e6d07a4f0d477ecbe4328a
# Data and Nonce Value:  b'Hello Kathmandu University!239'
# Hash Data : b35eaa192acc93c76864a3a14046d362407cac7d1a3a0d1fe5a406a45669de96
# Data and Nonce Value:  b'Hello Kathmandu University!240'
# Hash Data : 71007a7875aff051105e8e2a8d1825e8cd05cb5076bc8bdff31ff493545fd769
# Data and Nonce Value:  b'Hello Kathmandu University!241'
# Hash Data : 352491c434388d6a5aa870dfd3dc73c281aa9112128ca6bf35aa2a322d1355d0
# Data and Nonce Value:  b'Hello Kathmandu University!242'
# Hash Data : c5570c24e9e29ca6a87127ebc15d049473d55cda87f0d635256a616760792621
# Data and Nonce Value:  b'Hello Kathmandu University!243'
# Hash Data : a2464c6fdde4ed970d17632ecbf5feecd7f1761ae409d360120eac3adfcf2e5d
# Data and Nonce Value:  b'Hello Kathmandu University!244'
# Hash Data : 429e4b819c20af098b2da67147428abbf40efff48a41aa460d99dded0d5ff76c
# Data and Nonce Value:  b'Hello Kathmandu University!245'
# Hash Data : b0324dc7afcb2b6b68cc02aabf2c2884c7b122781a7025ecddaef16e9ecee150
# Data and Nonce Value:  b'Hello Kathmandu University!246'
# Hash Data : 3a3c20fabe20c86d3332f48360384dcb714ac4690489b545a3ad86e680467f05
# Data and Nonce Value:  b'Hello Kathmandu University!247'
# Hash Data : 21cb3deaeeb91d30a6077572149586ad400cb85c50a0fece9706c968f8229229
# Data and Nonce Value:  b'Hello Kathmandu University!248'
# Hash Data : 410ce4b1e67545b4f314aa1fe0f4d27845beaff1e734959ae0d2470f106a02d4
# Data and Nonce Value:  b'Hello Kathmandu University!249'
# Hash Data : 8b961774125efd258bf3da22bdb09d4d7c63a72eeae2e594da89dca59aaa64cc
# Data and Nonce Value:  b'Hello Kathmandu University!250'
# Hash Data : 867cf182f2bd50710296106a4bbec9418404521b34d85428b3db9c4c14279125
# Data and Nonce Value:  b'Hello Kathmandu University!251'
# Hash Data : 75f9983bd0874987e956f31a2c2b38e6b1b0da9a1cecd0beb67afbe7c6ac31df
# Data and Nonce Value:  b'Hello Kathmandu University!252'
# Hash Data : 4aec08c72384c1c219d0e41a96fef3c3e2689d5973d0d4cde32f5308c780ef77
# Data and Nonce Value:  b'Hello Kathmandu University!253'
# Hash Data : 585777721048cc02d26e7166fd1b7fafa471b593de227ebc74b9aa45d05952d8
# Data and Nonce Value:  b'Hello Kathmandu University!254'
# Hash Data : 4b611103390c775d89acd77525a15a06b5807b0964691cd65a26d772fa0849ae
# Data and Nonce Value:  b'Hello Kathmandu University!255'
# Hash Data : 95bf3a2aab7350aea5ebcf607655c362e0bd0b578e5ae84b3cc2aa38cdabb830
# Data and Nonce Value:  b'Hello Kathmandu University!256'
# Hash Data : 4ebcc6390d46ec171f79ba6453e8f047192ec6c21c94019828a54799333f06bd
# Data and Nonce Value:  b'Hello Kathmandu University!257'
# Hash Data : 691db1c935534cb9f5cbaeab3c40e4034e3a92e78e8e173b1c6b8e9e2dc42a0f
# Data and Nonce Value:  b'Hello Kathmandu University!258'
# Hash Data : e023689187c68c1f34c8c2cd469565d387627fc9780f071118414fdddee087c1
# Data and Nonce Value:  b'Hello Kathmandu University!259'
# Hash Data : 4e00b1d7369152b3ac8ed59ed50334a3a53c8c337105668212477be017fc1508
# Data and Nonce Value:  b'Hello Kathmandu University!260'
# Hash Data : bce5dcf846ccf77f76d28a19deede82a9f1aa9fd8f1a114e91ec8c12089e68f0
# Data and Nonce Value:  b'Hello Kathmandu University!261'
# Hash Data : 4e56fc8c218cdbb79f7ad98ee710e26ede7b9b3fdf0b418612617118d6978096
# Data and Nonce Value:  b'Hello Kathmandu University!262'
# Hash Data : 3fa1239a3eec4a43ba5aa32578c18a8ffe6ed27b43a190093f73f88d1bf4c4b6
# Data and Nonce Value:  b'Hello Kathmandu University!263'
# Hash Data : fd2f7649ffa7858885865efc42d03aa1d332dae54756586e58f7e93dd8bcf6e4
# Data and Nonce Value:  b'Hello Kathmandu University!264'
# Hash Data : 482287e50cf93fc210aa312540b09374e00e5d28df28508497004abf6544b762
# Data and Nonce Value:  b'Hello Kathmandu University!265'
# Hash Data : 595fe13902b6ef5869db367f5789404724c5a58130aaf8c8c53e68814b4f229a
# Data and Nonce Value:  b'Hello Kathmandu University!266'
# Hash Data : 14738bdc8e0e011a9c39fddda67f7df0dac52f754a258bb0ee516fb89547c7a7
# Data and Nonce Value:  b'Hello Kathmandu University!267'
# Hash Data : aaf142500055a0f94a0e5769740a62d1a4788ad0baf9e93f92818d10479a1ff1
# Data and Nonce Value:  b'Hello Kathmandu University!268'
# Hash Data : 66f613705ed380a485dfda7de66c56e1f74835f8751fcf6a97825bb2b11ce2e0
# Data and Nonce Value:  b'Hello Kathmandu University!269'
# Hash Data : 8a99f00c9eb48b1c4d626c2fd4cbc5d6b54bc29ada4158b3087a0653d9ef0c25
# Data and Nonce Value:  b'Hello Kathmandu University!270'
# Hash Data : 91fd0f442761703d44784c396d8fff21ddb458881f13ca90e24f215b5e273635
# Data and Nonce Value:  b'Hello Kathmandu University!271'
# Hash Data : 79c080d8da1eaabe350b08417941f89290138191fa0373de9e378051f3f7338a
# Data and Nonce Value:  b'Hello Kathmandu University!272'
# Hash Data : a1215ba8bd4b3cec018940586fa720634c274e44085757da097d195fdedcc612
# Data and Nonce Value:  b'Hello Kathmandu University!273'
# Hash Data : b1b11ae0ab146037cb40e7e9f73341e8cfe7863137900e729ccd676ad51a5bfe
# Data and Nonce Value:  b'Hello Kathmandu University!274'
# Hash Data : ae8d5319d397add7eccf7c063341fbd9047f11e43fb69d862babf9b2754e707f
# Data and Nonce Value:  b'Hello Kathmandu University!275'
# Hash Data : e022eaae44419accead54701f9d6c22c106069577a44a2b25acb94bd4414d12e
# Data and Nonce Value:  b'Hello Kathmandu University!276'
# Hash Data : 65c69cac04a0ecf911cd6213cfc6e15ef18e2d6d11a7dd3875c16bb8b5cb337c
# Data and Nonce Value:  b'Hello Kathmandu University!277'
# Hash Data : cc0fa7a7c9e01da30b300d5d252d82899b3f12daf09f0ff5fa317c8511c73347
# Data and Nonce Value:  b'Hello Kathmandu University!278'
# Hash Data : 55d1f0ed0b67ab743ec61ee28dd4ab5d1ccbe320fc75d5c888704ef1dcb132c3
# Data and Nonce Value:  b'Hello Kathmandu University!279'
# Hash Data : d2ca9aa3812f0c0c6d69ae7c4614301c6488f9595e41d1ee265a85afa016dd83
# Data and Nonce Value:  b'Hello Kathmandu University!280'
# Hash Data : 91f7907807b8d349651f4f9c8d16515573cd1f8004d5a849d063a8e80f63861f
# Data and Nonce Value:  b'Hello Kathmandu University!281'
# Hash Data : 8c4963e9ff4b3eab0228acee64a6d02ce1f77b3d5046c4377d6cbb7cee21f947
# Data and Nonce Value:  b'Hello Kathmandu University!282'
# Hash Data : df2c4306e5fa6a89087bcb13692b392e8b00d56f5174eaa967caa7459d45455c
# Data and Nonce Value:  b'Hello Kathmandu University!283'
# Hash Data : 957eadf40bb3500e08c370754a175a5cfb69daabe9b31057ea6ffa56f78fe6f5
# Data and Nonce Value:  b'Hello Kathmandu University!284'
# Hash Data : 3f8b473f537b052d8e4455c6880aeb1613ed40cb4e7989d88952a227f9567734
# Data and Nonce Value:  b'Hello Kathmandu University!285'
# Hash Data : 848a247ef2f506fceac13a49e4e05b2dca20f9778f51258fa5a0f2e331549693
# Data and Nonce Value:  b'Hello Kathmandu University!286'
# Hash Data : 4e06cebff1b0f25569e5921d136f812ae28cef20a3a695483b906a67a1c93684
# Data and Nonce Value:  b'Hello Kathmandu University!287'
# Hash Data : bdbed9560691d3e227c4d997f8c3c9652544dac005149e9e7e678d91f2c3848b
# Data and Nonce Value:  b'Hello Kathmandu University!288'
# Hash Data : fe7204571f47110a77fa0a7c5ff7037456472a7b114c8f636a59d4722ee6b633
# Data and Nonce Value:  b'Hello Kathmandu University!289'
# Hash Data : 7ab15d8d2206071c4f8e1aae5148d3e9c4e4ff1f58b4a488b3c0da246647a486
# Data and Nonce Value:  b'Hello Kathmandu University!290'
# Hash Data : 707b67140fb6889f09bf8265a5f8843c63328323da0f420c7adf535959f49bdf
# Data and Nonce Value:  b'Hello Kathmandu University!291'
# Hash Data : 502324688cb989b817db2ffd14551a235510cf262467684f9a8e42b344f17f40
# Data and Nonce Value:  b'Hello Kathmandu University!292'
# Hash Data : 8e1ce10768835075d8e6c9aad3f69341d1d0f4afce8c92894d3a225f04e7bf19
# Data and Nonce Value:  b'Hello Kathmandu University!293'
# Hash Data : 51143ae794301a5ca1b5af4c9f72daa29e87ce62a7b0509294a32438526a4de6
# Data and Nonce Value:  b'Hello Kathmandu University!294'
# Hash Data : ef623bb39a54109f35cfa138c520e9671518ae3b1ca49f69c5fb62af0ba94caa
# Data and Nonce Value:  b'Hello Kathmandu University!295'
# Hash Data : 96139bb29f6975cf72cd74aff26474b22a626db29194400064f7c0d0d304437f
# Data and Nonce Value:  b'Hello Kathmandu University!296'
# Hash Data : 3b5b41d0650a6fe87de0a217af33510c5c5ba9f186c0f748db061cd2841e532d
# Data and Nonce Value:  b'Hello Kathmandu University!297'
# Hash Data : 13541b3c4f3d9a66e4e7a0413ecbc7217ac160cf03bbaf17bb3cf463890b4cc2
# Data and Nonce Value:  b'Hello Kathmandu University!298'
# Hash Data : 6e1e1da5f48e1457a4853716b2d95f13610f12676cbe24992139263596eeb96f
# Data and Nonce Value:  b'Hello Kathmandu University!299'
# Hash Data : 38b942e6fd8d6a9507f2e2d2e2eb87e301975dc36fbfed1d6b883f7826cfa285
# Data and Nonce Value:  b'Hello Kathmandu University!300'
# Hash Data : 0652f77272f2232a593e80dd7d8f775ea44e46c16009267026ecf311fa7e1a2c
# Data and Nonce Value:  b'Hello Kathmandu University!301'
# Hash Data : ae40ce59d9b9bf9ad43c154da34267f391c36dbc7fc0f1cc363736f2f3c6e9d9
# Data and Nonce Value:  b'Hello Kathmandu University!302'
# Hash Data : af924267892f852e7a5a953146e1ceccec130a62e2faf9c5bb29b1db9d842c5d
# Data and Nonce Value:  b'Hello Kathmandu University!303'
# Hash Data : d0fe07c55f0e39aa3df6ac60e5bef5e8584ae3c58f9ad7876d0cbc1ee388d83c
# Data and Nonce Value:  b'Hello Kathmandu University!304'
# Hash Data : 54f69b6cd6adf45c9b08e5334c35eb2b0a368c2cc8b0b57ecb6ec74bea9f0574
# Data and Nonce Value:  b'Hello Kathmandu University!305'
# Hash Data : a7458cb0d5a7bb49a7c2c11bb655a5bdc1a4afd29322b1facfd3a985e5766ebb
# Data and Nonce Value:  b'Hello Kathmandu University!306'
# Hash Data : 259b6a827969d336a0c682a7ccbcc3498abf483918b88161f229e1dd2127f951
# Data and Nonce Value:  b'Hello Kathmandu University!307'
# Hash Data : c404d200a6cfba18ace432e2074be62f79f6ae737e6a32c82a174fba6208ecef
# Data and Nonce Value:  b'Hello Kathmandu University!308'
# Hash Data : 94128ffc7395e68777d69de21cd79dc1b9498c39a5a30d702646073d97aaa3cb
# Data and Nonce Value:  b'Hello Kathmandu University!309'
# Hash Data : a5f4393a96a7e2fa3cbeae6766797f122bc736e570d934ad6d84e2df770f47ca
# Data and Nonce Value:  b'Hello Kathmandu University!310'
# Hash Data : 78944c1c1024eba1d56c6eb7fe01443ee07906cd1638e7f8667a3e79834bfeb3
# Data and Nonce Value:  b'Hello Kathmandu University!311'
# Hash Data : 6153b67f3be56557e1e14d83b0fb07bbf046c4d53aca6fdc50c802740dbc7307
# Data and Nonce Value:  b'Hello Kathmandu University!312'
# Hash Data : c9126b49e0d96f32a6bef1f5117b4378036b64ebe99b7f0df5fd04da8beddb22
# Data and Nonce Value:  b'Hello Kathmandu University!313'
# Hash Data : 3cbf7f131384d8249dd793996226dbd2932d419682f7e6f09c8db4b38748a150
# Data and Nonce Value:  b'Hello Kathmandu University!314'
# Hash Data : c7e90ba920f396a0e6c6c6d9f933f9ecaa673d1ffba47a61cd1ef70098855fca
# Data and Nonce Value:  b'Hello Kathmandu University!315'
# Hash Data : f8f7ac67eda760f52eaf794efe00673e439419af5069ef8602e2343129653d5b
# Data and Nonce Value:  b'Hello Kathmandu University!316'
# Hash Data : 388e52088643c0971eb781c514024b64945aa2710fa9141a838b61354e0d646d
# Data and Nonce Value:  b'Hello Kathmandu University!317'
# Hash Data : 43a742a142f0aaed83d20cebd3fe5e3e70af79cda3cd610e27e16e95186e8c05
# Data and Nonce Value:  b'Hello Kathmandu University!318'
# Hash Data : a69ade31126e91dc2f9ab1b236ec25672427c077e4f0aac796db2b13f1a8d281
# Data and Nonce Value:  b'Hello Kathmandu University!319'
# Hash Data : db2edfa6f30b4f3196130ccb7d70b8a5c5254edc06b51f8e6336c08b8fb0c6f1
# Data and Nonce Value:  b'Hello Kathmandu University!320'
# Hash Data : 651ad16ab920c247da5514a191ec59bcd2dbf332d29019941346957df4c14c95
# Data and Nonce Value:  b'Hello Kathmandu University!321'
# Hash Data : 89e1ad2aed7472be2a4a3dfa9b15949831630a0d77cc9c391b1d2f201e81a8e3
# Data and Nonce Value:  b'Hello Kathmandu University!322'
# Hash Data : 2e3f411d409e003dcea5ba3f9412b01826f999191f5c822302ad1e1dd48253d4
# Data and Nonce Value:  b'Hello Kathmandu University!323'
# Hash Data : 5b837e4efb2569510706a9670516e16d11f7cecb18f53218950b00d3e57aa825
# Data and Nonce Value:  b'Hello Kathmandu University!324'
# Hash Data : ffdac459a941b5a79df88381e1a0eb6628aeda6a713a94b2b880d4cda02e1d10
# Data and Nonce Value:  b'Hello Kathmandu University!325'
# Hash Data : bca46ec728d56006462bffc5f8c6fb28eeace6152158ac1f5f6211d055ce4070
# Data and Nonce Value:  b'Hello Kathmandu University!326'
# Hash Data : 6be9dbc8fd028727723d1a9ba828f4d0b26617e7ef7d4cf9da2003aba85dd030
# Data and Nonce Value:  b'Hello Kathmandu University!327'
# Hash Data : d263b105f91c74206980bbe08c17574a05d9439323abb59a6539f6842f43ec66
# Data and Nonce Value:  b'Hello Kathmandu University!328'
# Hash Data : 7de39a6b5cf3a2ca6207628b0be56ed235ae6e0b6fa3ce9f4ba45d3881a26227
# Data and Nonce Value:  b'Hello Kathmandu University!329'
# Hash Data : d6ea2f38974a685e370b696bf1080d4d1bbc0d3ca4f088037fa2338723c364b2
# Data and Nonce Value:  b'Hello Kathmandu University!330'
# Hash Data : 511510f8eae14b964c4e496bb5d3afbba95fc5703bc3500fa18e03fde043c1f5
# Data and Nonce Value:  b'Hello Kathmandu University!331'
# Hash Data : 9cfd7f2f0e2f551bb75eb047f29f9aeab88d9281887dd7df87e04246e39ecaa9
# Data and Nonce Value:  b'Hello Kathmandu University!332'
# Hash Data : 8a79d5f54b4ef0e272acba349a2187e0e59c82f60c4025d72ab0e8decefd40ce
# Data and Nonce Value:  b'Hello Kathmandu University!333'
# Hash Data : 0b6c0b79f8ac150b971de784879ec1b24173c789946bbb59237027b28ca7834c
# Data and Nonce Value:  b'Hello Kathmandu University!334'
# Hash Data : afae388fad72a30608dad74d40d33fbc142e484d1b1ba91b2616fffc3b468c35
# Data and Nonce Value:  b'Hello Kathmandu University!335'
# Hash Data : 520c94bdb7c768c833da9cb00c5cbaefbfcb2acefd7c308d7bd56562711d8e3f
# Data and Nonce Value:  b'Hello Kathmandu University!336'
# Hash Data : 6f83b87d91fffe11068a423ace6e8a38afb1271503a574dc11977c370bc5c2ab
# Data and Nonce Value:  b'Hello Kathmandu University!337'
# Hash Data : ac5a18938e6414391f35775990e6e455023aade7b7a930edcba7cf0b2fb37733
# Data and Nonce Value:  b'Hello Kathmandu University!338'
# Hash Data : d17d36eb698e53f769c496fcabc6045d58eac4c3d64991a387ba84743488c47b
# Data and Nonce Value:  b'Hello Kathmandu University!339'
# Hash Data : ceaca256dbe040bd3cb65a09edc068c51e5542fcadf564761c5328003250b7d5
# Data and Nonce Value:  b'Hello Kathmandu University!340'
# Hash Data : a2344b6f3881f86fa50da176bea0a915d78fe8351601929984f9e78071342f47
# Data and Nonce Value:  b'Hello Kathmandu University!341'
# Hash Data : b95e814400ed28711ac2dfabf60549e453a76145a89e47732614bc1214359a8a
# Data and Nonce Value:  b'Hello Kathmandu University!342'
# Hash Data : 4f0f7d465fd25007b21a346d7a66b8dadb5e53b695c1665b45ec4f71605548c5
# Data and Nonce Value:  b'Hello Kathmandu University!343'
# Hash Data : d28ea750c9399a3c28a9cd61033702e01f254b9e345da969da0e0368b5ff75d1
# Data and Nonce Value:  b'Hello Kathmandu University!344'
# Hash Data : 707e23bb82def3dcf509add457ab9981e8161f77cd278a81ac713f4c9d96be04
# Data and Nonce Value:  b'Hello Kathmandu University!345'
# Hash Data : b67dbae046a67c0fc7d757d1bc622cc78297472f8efd0eca06ae0c9609f804eb
# Data and Nonce Value:  b'Hello Kathmandu University!346'
# Hash Data : 63bc9cc5bb5261f5d0d45c9501057f868033c5f8ffc7a6f18f486e61d4b6d0fd
# Data and Nonce Value:  b'Hello Kathmandu University!347'
# Hash Data : 691b15e90c93ecc9d506b6c07b56cdb01a196310093a41043e6e85e8efe1b775
# Data and Nonce Value:  b'Hello Kathmandu University!348'
# Hash Data : c13349b2a20e6b05cddccdc6ca4ba4ebb48c672cf034b3e7867557953d2343d6
# Data and Nonce Value:  b'Hello Kathmandu University!349'
# Hash Data : 45b5edef8a78d035692466925e2dc49cb14df6ad75343f42b1279654b0b87184
# Data and Nonce Value:  b'Hello Kathmandu University!350'
# Hash Data : 53e491d8b9cd9220f1e108bcb8e82712f421b3f4d8c90a64987e1f718cae5add
# Data and Nonce Value:  b'Hello Kathmandu University!351'
# Hash Data : 757bfb09f826f21f342312042e0897bfc44ab64050b467bd002e949a6fd0b957
# Data and Nonce Value:  b'Hello Kathmandu University!352'
# Hash Data : 14f515696bb355fa39bc228e23056182f578bdec07ad1c32fc4ef3dd51ab95db
# Data and Nonce Value:  b'Hello Kathmandu University!353'
# Hash Data : 96712a4d9e54fa292ed6db0b1d16415c94fca58fcea598f218f593a8f2ecad5e
# Data and Nonce Value:  b'Hello Kathmandu University!354'
# Hash Data : 35ea38359f560367b55cbc64a4e841fb553dd4508fb20f103edb36d13fb751c6
# Data and Nonce Value:  b'Hello Kathmandu University!355'
# Hash Data : 7a83d69df3027afd2097c204954c9ac54a5a3ad55e4630401909307b421144ed
# Data and Nonce Value:  b'Hello Kathmandu University!356'
# Hash Data : 59a5f615355670947f99ee60af34fad43dce3bae74a442a752c25218af807a10
# Data and Nonce Value:  b'Hello Kathmandu University!357'
# Hash Data : d8054d7a383622ca8a94a4ee4eec327cbde148eda2fd80fad1eedbc2d69419e2
# Data and Nonce Value:  b'Hello Kathmandu University!358'
# Hash Data : 075389fe50d040430f632332dd73ac5164e4089feff7845acb229579e59ee8ea
# ...
# Hash Data : e5e8aa32564d86d49327ba28ddd5ae06fac1696fe87d69ca3f3a6c42f473c30c
# Data and Nonce Value:  b'Hello Kathmandu University!2073'
# Hash Data : 67297347d80a59381531f7cacc403a619dda9188bac99d1074a5f14f3e51797a
# Data and Nonce Value:  b'Hello Kathmandu University!2074'
# Hash Data : c6c150db3346c87957371080ceaf51bc123fbd82f002157617040b0ac9529b00
# Data and Nonce Value:  b'Hello Kathmandu University!2075'
# Hash Data : 86c9230c14bde63ef0ad1f518cfe11211b9004c5d00927fc40927716c159de5d
# Data and Nonce Value:  b'Hello Kathmandu University!2076'
# Hash Data : 85e58dc6dc209ff423c676d62d6cebd80af273dbb77049b08182fa0841d63a1b
# Data and Nonce Value:  b'Hello Kathmandu University!2077'
# Hash Data : d29d786ddb41afaad9250c46b9493a98799dd43ee685ecef358ae53cb01922dc
# Data and Nonce Value:  b'Hello Kathmandu University!2078'
# Hash Data : 2e451c98a1f5b6c19bcecd3b5b62f9001eb63a72a725c28046c5bb7c42c6772d
# Data and Nonce Value:  b'Hello Kathmandu University!2079'
# Hash Data : 09d2187db7ab10874632893f1111506a4968e56e611023204c4318abbf2aeaab
# Data and Nonce Value:  b'Hello Kathmandu University!2080'
# Hash Data : 370a083b49db3f6b2a362f6c60b5d0034100ec4dbbb48471a6a8bf033d613183
# Data and Nonce Value:  b'Hello Kathmandu University!2081'
# Hash Data : a6e2ba8705d77c56d8e47927b2d58199e35b93b2a2ee8669f94f71b02447173c
# Data and Nonce Value:  b'Hello Kathmandu University!2082'
# Hash Data : 1a17f975bd75fc4bc35d5bf20d0ec9498d3bb565968caccfe29239add41c582c
# Data and Nonce Value:  b'Hello Kathmandu University!2083'
# Hash Data : f6683d2f2299d05404d5bcb685bd5b11f844f81cf43908a03a9959da0bfd1e6f
# Data and Nonce Value:  b'Hello Kathmandu University!2084'
# Hash Data : ebec27cdc8300a7049116fbc9714077e713c62c2773c7a2ec66bad82be40b14d
# Data and Nonce Value:  b'Hello Kathmandu University!2085'
# Hash Data : 59dcd88c051d99af3c6a8ad310ae90863bdc39b66e20754f12a3d1726f62a193
# Data and Nonce Value:  b'Hello Kathmandu University!2086'
# Hash Data : 6efd8650f86e3e284be0d64294d12d7c05882ee09f1b2e1369faebdde4a88de7
# Data and Nonce Value:  b'Hello Kathmandu University!2087'
# Hash Data : 7693d6e56ad9cbd2a105ec23b175d6a096b9c1c3884b6942d8ad71a25ffe9c80
# Data and Nonce Value:  b'Hello Kathmandu University!2088'
# Hash Data : 4703f09c513e99f8c519b1e32c3acf6dd5169b4afcc1a75c5fcb20ca3cda1d5c
# Data and Nonce Value:  b'Hello Kathmandu University!2089'
# Hash Data : d9a62d6706b07d435088bd40e8491f6dc9bff4e12f0f7f4703463847b63c4890
# Data and Nonce Value:  b'Hello Kathmandu University!2090'
# Hash Data : 31372f6322dbc9eadb006f5bd0c3008f3197b7b789d70a4e7d1eeb285aa15a82
# Data and Nonce Value:  b'Hello Kathmandu University!2091'
# Hash Data : dd21e5a4fcb15712031f6b4c148fd30950fb4aec645628debd6236b8ef722bd7
# Data and Nonce Value:  b'Hello Kathmandu University!2092'
# Hash Data : 3972b95fe421986491f1c26e3d1c9fc1bf0e33b3a20a1f45f10def48cedf62b8
# Data and Nonce Value:  b'Hello Kathmandu University!2093'
# Hash Data : db7e551992e69d23560bc03728c4c91702c4265839a727a759ab0b1ca59b6d93
# Data and Nonce Value:  b'Hello Kathmandu University!2094'
# Hash Data : 215821212d60b138fe08857593a4007e230c39a667e8b439f2a8084bf7c6a5ba
# Data and Nonce Value:  b'Hello Kathmandu University!2095'
# Hash Data : 4ad69fb7c05dae51105ed9e15a1a103fe12fff3ba5774bae4a3d353a6f9f85e2
# Data and Nonce Value:  b'Hello Kathmandu University!2096'
# Hash Data : b42c1fb80c9942afaa06ef43dfc55694c8cb966a1e72e3c0799fd74d607e1c1a
# Data and Nonce Value:  b'Hello Kathmandu University!2097'
# Hash Data : 9722e23f5cd44466a606aac3a54c700de3664b00bd372a142825be9b539466f5
# Data and Nonce Value:  b'Hello Kathmandu University!2098'
# Hash Data : 13d4c3fc9cb4a752feb2f53c9ac48e00eeaa783f5134d0fe16f9a054c4f4486c
# Data and Nonce Value:  b'Hello Kathmandu University!2099'
# Hash Data : fd4c99c23db9f45a97cf5fd455fd65854e3385c1cc6b710765822ae3c5fce851
# Data and Nonce Value:  b'Hello Kathmandu University!2100'
# Hash Data : 3aaf3dac703d32fc5057ad3154f5817904a49630ae0ef7966a8e096ff22fb1a3
# Data and Nonce Value:  b'Hello Kathmandu University!2101'
# Hash Data : 41fb79f3733d02fda563d4296482d7a6da6b4c673114cfad2fd694ba1d349601
# Data and Nonce Value:  b'Hello Kathmandu University!2102'
# Hash Data : 292727162442e769007a41b6a0aa67cfe6b19467717e9b43bee387586fa40656
# Data and Nonce Value:  b'Hello Kathmandu University!2103'
# Hash Data : 4dee80f33061d192cc33cad420efd022219d439127d1f4b25df4a1a7abda3950
# Data and Nonce Value:  b'Hello Kathmandu University!2104'
# Hash Data : b160f04a3797944e6c4e1008b84dba2323317f689c056b286411fd17ff2ee889
# Data and Nonce Value:  b'Hello Kathmandu University!2105'
# Hash Data : c74f06eeb503ab292e6ad43485ea39044f16bedf0b15f2a0da47bf43d1fcfb6c
# Data and Nonce Value:  b'Hello Kathmandu University!2106'
# Hash Data : 02f80bd30c28ba88e22603eb67421a9b3ca5026898f8caa8cd159408019048a4
# Data and Nonce Value:  b'Hello Kathmandu University!2107'
# Hash Data : ee6465a49d89d3c3d3fc759a948614670ae11443dbe9736db5d4d2851c55277d
# Data and Nonce Value:  b'Hello Kathmandu University!2108'
# Hash Data : de2220ed848dda51e9a8feaf46061eb7853a6a534f5fa5e74a06530cca45adc6
# Data and Nonce Value:  b'Hello Kathmandu University!2109'
# Hash Data : 3e45e24a5dc4aa98fdc4a92c905364d280c7786f74585c5047dad5b3d52ced22
# Data and Nonce Value:  b'Hello Kathmandu University!2110'
# Hash Data : 438d7f6ecd6604a467f275b03d2d0463103ffd1756218b64ecdf4979b8d8bcf7
# Data and Nonce Value:  b'Hello Kathmandu University!2111'
# Hash Data : 205079579de662f1e77ba1463dc2cf6e45f15aabd56417305554ceb1b1f98bb5
# Data and Nonce Value:  b'Hello Kathmandu University!2112'
# Hash Data : 2555a1e62d3b77ab7303c874fbda9bcc9075e59fa3a7dd4a28bcc278e941ef7c
# Data and Nonce Value:  b'Hello Kathmandu University!2113'
# Hash Data : 757ac3f2d98a0cd539ec1ced3579ec9206592ea2aae66a1c0c10361d44272196
# Data and Nonce Value:  b'Hello Kathmandu University!2114'
# Hash Data : d0c47da098d98381c1698dd35b74b6a25fdfeb41792ef9ab000c3a8b343590f0
# Data and Nonce Value:  b'Hello Kathmandu University!2115'
# Hash Data : 8275116b2e4066cc0a8a7bd5569dccf940d9ed14e3f429b96c4d8d42d464b967
# Data and Nonce Value:  b'Hello Kathmandu University!2116'
# Hash Data : fc9f67a9aa54931cda35611fdbf00861b2314e35b564c67150dd1cf01ee47463
# Data and Nonce Value:  b'Hello Kathmandu University!2117'
# Hash Data : da531b4b667ef7b100a69ad4cc286d826c38f2dcd13cf7d6d99206552b4cbfbe
# Data and Nonce Value:  b'Hello Kathmandu University!2118'
# Hash Data : 0b3c90942c660afd89abce48e635d92abde8ae37047dc79f6d46787fb2bbae16
# Data and Nonce Value:  b'Hello Kathmandu University!2119'
# Hash Data : 61d8e7b227959e369ba31ae449248517abf217fa6bd9828148d74eebc852f55c
# Data and Nonce Value:  b'Hello Kathmandu University!2120'
# Hash Data : b62508a97157eddd98444e5a4df0353431cdadd4196c07108ebd9221adf4c5bd
# Data and Nonce Value:  b'Hello Kathmandu University!2121'
# Hash Data : e45ba28ea2a1ac5929f75454f970e8ee1be05ee311295735de7daec2377108a1
# Data and Nonce Value:  b'Hello Kathmandu University!2122'
# Hash Data : b33bdc0dc123bd1ed7e25172efceb0390e8e43da922d6d6f854196fe78b68ca2
# Data and Nonce Value:  b'Hello Kathmandu University!2123'
# Hash Data : c813b3bc334cb82e69ed422f84f53b9c8e3e9838aea8dc2a896516d1336e07a9
# Data and Nonce Value:  b'Hello Kathmandu University!2124'
# Hash Data : 94dd69790c32fbe799360bc548398c916f458488e8907332e0bb60d59e06dde4
# Data and Nonce Value:  b'Hello Kathmandu University!2125'
# Hash Data : 0f441ff4631ebfde2fba277b60245a24a96cd1c09aaca14d40f6c676b9af022c
# Data and Nonce Value:  b'Hello Kathmandu University!2126'
# Hash Data : d8595fd976d7ac971121c5db5377e8cad11b10944ed200c2316b3e48203d5afc
# Data and Nonce Value:  b'Hello Kathmandu University!2127'
# Hash Data : c3960e954b33d10b1f5848ffeba278a37fb990a43cf78fa8ff7938227ae3faff
# Data and Nonce Value:  b'Hello Kathmandu University!2128'
# Hash Data : a6278358520967bf0e2d5063de87a53819337cd416e744118ef273be003dda11
# Data and Nonce Value:  b'Hello Kathmandu University!2129'
# Hash Data : 1b9fd45b2500178b01b20433ba4e0934279ab2562f7f55a0f8b36ef61c0844ce
# Data and Nonce Value:  b'Hello Kathmandu University!2130'
# Hash Data : 0734953c15b53be0da251fbcd7fa066f43076ab8067553df54bfaee9b9dddf06
# Data and Nonce Value:  b'Hello Kathmandu University!2131'
# Hash Data : 81f500accbe06b2c10806fdda4f6145c6ec77ad348076635696d902c2bca5130
# Data and Nonce Value:  b'Hello Kathmandu University!2132'
# Hash Data : d64c7314a6b48de5772baf02446a2dee1526d426d94a8d592c9c458b3457105e
# Data and Nonce Value:  b'Hello Kathmandu University!2133'
# Hash Data : ce054902c7606179512c359be2dbea841a050d0f28d8d2217f8ef25f7bf0f33f
# Data and Nonce Value:  b'Hello Kathmandu University!2134'
# Hash Data : e59d1970f92536c6c28eec0cbc6d2bac01a86f9a1352ca57ded9b5905f03f1f0
# Data and Nonce Value:  b'Hello Kathmandu University!2135'
# Hash Data : cb073a088fcf25a3d76504e638b770bcfdc6d29eb7f51ca3cb4c190c67f4f984
# Data and Nonce Value:  b'Hello Kathmandu University!2136'
# Hash Data : 9d79a7b1ab22ad82520e786c4f01360dd7c9765c3823d73a0d246c945721dfa0
# Data and Nonce Value:  b'Hello Kathmandu University!2137'
# Hash Data : 18c96d2cafe53afcad11aacd24ab0814fd2d6a4dcbe37c42b7c81649e74bf1a6
# Data and Nonce Value:  b'Hello Kathmandu University!2138'
# Hash Data : afd961cf311dadbd597b10858bf2b22090bce6aa9cdf9a4e9ddbaef67c79c44a
# Data and Nonce Value:  b'Hello Kathmandu University!2139'
# Hash Data : 77522883425df712cdce326cd796c2397597e7831fbfd548b9d77fcce6292510
# Data and Nonce Value:  b'Hello Kathmandu University!2140'
# Hash Data : 07b0953d81d71833f9f627fc4359cee7c4888c305fab74f523eae9dd4427e9fc
# Data and Nonce Value:  b'Hello Kathmandu University!2141'
# Hash Data : 7c3ea4756c893512d5f70b8a815b35a4ed27bf4bd8a889a6f8580c77570c4ee1
# Data and Nonce Value:  b'Hello Kathmandu University!2142'
# Hash Data : cbf56213ee70c5e13ed563d3c7263a3563983ebf690b65577ebf3064b9f8bf85
# Data and Nonce Value:  b'Hello Kathmandu University!2143'
# Hash Data : 67ef70f8327689a917df2aa8418d08bb6fff49f999e2f6ce1461b1a449f6d27c
# Data and Nonce Value:  b'Hello Kathmandu University!2144'
# Hash Data : cac6b3bb5f2e11db8690dbbc71024097fa6c0ae5a2f13e76cabc16c5f7622247
# Data and Nonce Value:  b'Hello Kathmandu University!2145'
# Hash Data : 7a4194bf87e63864c8227ab4eaa7568a7ba310b1e030ab5f07d039bf805cff53
# Data and Nonce Value:  b'Hello Kathmandu University!2146'
# Hash Data : d9f897202b572655b6dbd7bd6242989e6f46b9d1761681dfda789e346fd619de
# Data and Nonce Value:  b'Hello Kathmandu University!2147'
# Hash Data : cac544fafb1cb18338787dd0ba5d1bc93f7fe5b04a7a75d47d763fffe3439423
# Data and Nonce Value:  b'Hello Kathmandu University!2148'
# Hash Data : ffaf1c9b5145f3231b74be0e15aab6793c152c7dfce606af4ecff8ee4171156f
# Data and Nonce Value:  b'Hello Kathmandu University!2149'
# Hash Data : 02d07b6e31f87ce5f0072183caacb2c6c17c9fbe484ee9d2ec52f35f9652aaf7
# Data and Nonce Value:  b'Hello Kathmandu University!2150'
# Hash Data : 0db46b596baa42230e2347620ba0bbb6292a6ea599dcd7b561f3b162114bb59e
# Data and Nonce Value:  b'Hello Kathmandu University!2151'
# Hash Data : eca0c17ea58d01a707984f3c9f34c90397b8721b14605a3557950e61e0fd79b5
# Data and Nonce Value:  b'Hello Kathmandu University!2152'
# Hash Data : d8f45a4034ec75cc99be3621d672c605e7e47d560b84955920a9299ebe5ac93c
# Data and Nonce Value:  b'Hello Kathmandu University!2153'
# Hash Data : da545a5c4411bcad727dcdad43d292a81c211f0b388130431700385fb78c5c24
# Data and Nonce Value:  b'Hello Kathmandu University!2154'
# Hash Data : fd3761c3155be6f3851bf104595fdeddc823aeba85e9f423aba9d29bfe61054d
# Data and Nonce Value:  b'Hello Kathmandu University!2155'
# Hash Data : 30140e532e9dd1b7a6a6763910d0ed2778aeb3267c7b584e81462e98a1f1bbb0
# Data and Nonce Value:  b'Hello Kathmandu University!2156'
# Hash Data : 7dfb420eadb62ac531ba61970710a2f1312292993e954ac448eb062945f42a9e
# Data and Nonce Value:  b'Hello Kathmandu University!2157'
# Hash Data : 3c3eb8ea1cbd256033254c36626a5c1380cd1c932f2e1f1c6f51066f0a875ad1
# Data and Nonce Value:  b'Hello Kathmandu University!2158'
# Hash Data : bbaf5eb2ba3cd14ff05eab72a091fcf6087c126f07fa02cbbca5e392a646c6a5
# Data and Nonce Value:  b'Hello Kathmandu University!2159'
# Hash Data : c3926abc031206f86874a96ed0a32e80118c59b0e2a43a428d94b855d950537b
# Data and Nonce Value:  b'Hello Kathmandu University!2160'
# Hash Data : 0c9e7ad5410c67acd6cd2fc2285b3dd1c6d9e5a2fafcbb192fe1b1d69d3b1f10
# Data and Nonce Value:  b'Hello Kathmandu University!2161'
# Hash Data : d54f6241b6da8d07b561da9acf92056b727e578786fa9a8e1fe174610f86ec37
# Data and Nonce Value:  b'Hello Kathmandu University!2162'
# Hash Data : e377b4d4d2b44a898595fe09d2ff9b1c8e18f9c4d5fab7a18e0bc1cfa81d1baf
# Data and Nonce Value:  b'Hello Kathmandu University!2163'
# Hash Data : 6966b6cfa6eadb7803db5d8a7393ed474687fc8ea24b8de8974097369db06aad
# Data and Nonce Value:  b'Hello Kathmandu University!2164'
# Hash Data : ea2fe92a27220476a51df637c4153cd2934c996b36a33febc854f814c8834ca4
# Data and Nonce Value:  b'Hello Kathmandu University!2165'
# Hash Data : 685fb555d27643fb397bd407017324b03ea785ed3902c1c10da0a52c9d153d50
# Data and Nonce Value:  b'Hello Kathmandu University!2166'
# Hash Data : 2e0bd442f0feedd2ab8b63a1114d5fade9362fc76550fc5ed9cc90e97721b9d7
# Data and Nonce Value:  b'Hello Kathmandu University!2167'
# Hash Data : 936af04313e86bfd615e82083bba46cc77f8fdd94dc49a15520578b80d2ebe59
# Data and Nonce Value:  b'Hello Kathmandu University!2168'
# Hash Data : fb0b18fd32cbdd92bc7e22157c30bbacffd87ded4d13ebd5f179f3c322a43856
# Data and Nonce Value:  b'Hello Kathmandu University!2169'
# Hash Data : fd568bdd3c5fe4b583ba447714c3c8557c62f6d6c1c1a4d1fcf50f28ff09bf5e
# Data and Nonce Value:  b'Hello Kathmandu University!2170'
# Hash Data : 11ff3bc1e9f7eebaa0df413cdde6d00f6354308d41fc0e06dfa26745a04e49c1
# Data and Nonce Value:  b'Hello Kathmandu University!2171'
# Hash Data : c1987b31444251d79feeeff88ab20cf103e6fab1b6ea9b3d66199b732a6afcfd
# Data and Nonce Value:  b'Hello Kathmandu University!2172'
# Hash Data : 1bab546324e0bc6c8787eae3630c87a65c28089390407306a521271fb732f238
# Data and Nonce Value:  b'Hello Kathmandu University!2173'
# Hash Data : 90ca24be686ef390bf9b9544dc759ae377fa64b05bc1951fd4211fd5e7a8b108
# Data and Nonce Value:  b'Hello Kathmandu University!2174'
# Hash Data : 612f07b9c3c1c0aaa482b54c7694aa4f9c211d7c5a4c9c79c510b1542fa7f045
# Data and Nonce Value:  b'Hello Kathmandu University!2175'
# Hash Data : b5929c9efaff9459171de58325b2530276dc8d843be08fc00d9d05d0c544d0b7
# Data and Nonce Value:  b'Hello Kathmandu University!2176'
# Hash Data : c98a7fa98708cf196b733feee8b0f67b487c8a797a1014102e037dd4c60cf98a
# Data and Nonce Value:  b'Hello Kathmandu University!2177'
# Hash Data : bb794ff41dd0e3d2c06040d9baacece93143422a874b9380435efff6aaa10349
# Data and Nonce Value:  b'Hello Kathmandu University!2178'
# Hash Data : 5ee9781ed5ebab0f91d895db427e385392198356691b75fc14357d44034a2e11
# Data and Nonce Value:  b'Hello Kathmandu University!2179'
# Hash Data : 12857ef11773e7262729f9c8d88098399ec896d905cb9d9ffa12c890ee2a4cd9
# Data and Nonce Value:  b'Hello Kathmandu University!2180'
# Hash Data : 11eb409a75a605cc18b335f1d17e8571522122375bfd474ccaa9623190774668
# Data and Nonce Value:  b'Hello Kathmandu University!2181'
# Hash Data : 14df295240076c292872d66a14a17754b1934d27e287367e283b037d909ea6fa
# Data and Nonce Value:  b'Hello Kathmandu University!2182'
# Hash Data : ef7bff7ed6eaf548ddebaf93cebbfa81664e561a85fd8d4db9ae04a45a0c363e
# Data and Nonce Value:  b'Hello Kathmandu University!2183'
# Hash Data : 1c1da8733a520f11fc56c3b146c8465a84c4b1112b92bd387c3419e5e5198448
# Data and Nonce Value:  b'Hello Kathmandu University!2184'
# Hash Data : d365fb1d087f7f5ea1783d481773399fdf9d224ff3bea5a0ba5988ff66716ecb
# Data and Nonce Value:  b'Hello Kathmandu University!2185'
# Hash Data : a48f2f4b8558b010b6e98acbca8c49ee12adb574c048154e09d6a8cc69b6eaac
# Data and Nonce Value:  b'Hello Kathmandu University!2186'
# Hash Data : 151c9b053f1e767e1bd770f38d1d338afb8cb232302a00164e8bc9332e40c76b
# Data and Nonce Value:  b'Hello Kathmandu University!2187'
# Hash Data : 343e6f1068bd8cf60705c510bd7f2b185fac8deee4d902d36e949300b04b3b70
# Data and Nonce Value:  b'Hello Kathmandu University!2188'
# Hash Data : 836317949e6588039795945ae267d6d1f86488aa1a4bf158af605e02ba635a80
# Data and Nonce Value:  b'Hello Kathmandu University!2189'
# Hash Data : 000c037c341f43e0a21c27409239d13f89fe7cfe9d23750cff3d2b954f6c8ade
# Found a valid nonce (Encode Format): 2189
# Hash: 000c037c341f43e0a21c27409239d13f89fe7cfe9d23750cff3d2b954f6c8ade

# %%
#
# Proof of Authority (PoW) Practice
#
# Proof of Authority (PoA) is a consensus mechanism used in blockchain networks 
# where the authority to validate transactions is given to a pre-selected group 
# of nodes. These nodes, called validators, are responsible for verifying transactions 
# and adding them to the blockchain.
#
# import the necessary libraries
import hashlib

# define the validator nodes
validators = ["node1", "node2", "node3"]

# define the blockchain as a list
# will simulate as if it's a blockchan trail
blockchain = []

# define a function to check if a node is a validator
def is_validator(node):
    if node in validators:
        return True
    else:
        return False

# define a function to validate a transaction
def validate_transaction(transaction, node):
    if is_validator(node):
        # calculate the hash of the transaction
        transaction_hash = hashlib.sha256(transaction.encode()).hexdigest()
        # add the transaction to the blockchain
        add_to_blockchain(transaction_hash)
        return True
    else:
        return False

# define a function to add a transaction to the blockchain
def add_to_blockchain(transaction_hash):
    # add the transaction to the blockchain
    blockchain.append(transaction_hash)

# test the code with positive case
transaction = "send 10 tokens from Alice to Bob"
node = "node1"
if validate_transaction(transaction, node):
    print("Transaction added to blockchain.")
else:
    print("Transaction rejected. Node {} is not a validator.".format(node))

# test the code with negative case
transaction = "send 10 tokens from Alice to Bob"
# Non validator node10 sending the requesting
node = "node10"
if validate_transaction(transaction, node):
    print("Transaction added to blockchain.")
else:
    print("Transaction rejected. Node {} is not a validator.".format(node))
# Out:
# Transaction added to blockchain.
# Transaction rejected. Node node10 is not a validator.

# %%
#
# Proof of Stake (PoS) Practice
#
# Proof of Stake (PoS) is a consensus mechanism used in blockchain networks where 
# the authority to validate transactions is determined by the amount of stake 
# (or resources) a node holds in the network.
#
# To DO:
# PoS also can account reputation, age of stake, and node performance
import random

# define the validator nodes
# also has the amount of stake hold by nodes
validators = {
    "node1": 250, 
    "node2": 251, 
    "node3": 10
}

# define a function to validate a transaction
def validate_transaction(transaction):
    # Select a validator, higher the stake more chance to get minning opportunity
    total_stake = sum(validators.values())
    validator_stake = [stake/total_stake for stake in validators.values()]
    validator = random.choices(list(validators.keys()),weights=validator_stake)[0]
    # Calculate the hash of the transaction
    transaction_hash = hashlib.sha256(transaction.encode()).hexdigest()
    # Add the transaction to the blockchain
    add_to_blockchain(transaction_hash, validator)
    return validator

# define a function to add a transaction to the blockchain
def add_to_blockchain(transaction_hash, validator):
    # add the transaction to the blockchain
    blockchain.append({"hash": transaction_hash, "validator": validator})

# test the code
count = 0
while count<10:
  transaction = "send 10 tokens from Alice to Bob"
  validator = validate_transaction(transaction)
  print("Transaction added to blockchain by validator:", validator)
  count += 1
# Out:
# Transaction added to blockchain by validator: node2
# Transaction added to blockchain by validator: node1
# Transaction added to blockchain by validator: node2
# Transaction added to blockchain by validator: node2
# Transaction added to blockchain by validator: node2
# Transaction added to blockchain by validator: node1
# Transaction added to blockchain by validator: node1
# Transaction added to blockchain by validator: node1
# Transaction added to blockchain by validator: node1
# Transaction added to blockchain by validator: node2
